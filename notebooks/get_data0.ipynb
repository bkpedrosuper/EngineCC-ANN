# %% [markdown]
# # Gather Data

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', 
                  font_scale=1, color_codes=True, rc=None)

# %% [markdown]
# ## Get Data

# %%
data_path = '../data/MotorUniversal_2k_5kHz_SemNorm.xlsx'
data = pd.read_excel(data_path)

data.head()
# Out:
#    Estado  Corrente  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0       0  0.717573    0.714725    0.704585    0.694305    0.687011
# 1       0  0.719402    0.717330    0.708022    0.698305    0.691041
# 2       0  0.723090    0.721113    0.711632    0.701274    0.692945
# 3       0  0.729627    0.726485    0.715613    0.704214    0.695404
# 4       0  0.714636    0.714388    0.706626    0.698127    0.691818
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 1991  \
# 0    0.683188    0.682031    0.682287    0.682855  ...      22.574360
# 1    0.686480    0.683860    0.682345    0.681356  ...      21.606304
# 2    0.687295    0.683872    0.682021    4.548630  ...      21.920634
# 3    0.689836    0.686908    0.685656    0.685570  ...      21.762202
# 4    0.688184    0.686566    0.686016    0.685919  ...      22.371510
#
#    Unnamed: 1992  Unnamed: 1993  Unnamed: 1994  Unnamed: 1995  Unnamed: 1996  \
# ...

# %% [markdown]
# ### Transform columns

# %%
columns = ['state'] + [f'current_{i}' for i in range(1, 1001)] + [f'volt_{i}' for i in range(1, 1001)]
columns

data.columns = columns

data
# Out:
#      state  current_1  current_2  current_3  current_4  current_5  current_6  \
# 0        0   0.717573   0.714725   0.704585   0.694305   0.687011   0.683188
# 1        0   0.719402   0.717330   0.708022   0.698305   0.691041   0.686480
# 2        0   0.723090   0.721113   0.711632   0.701274   0.692945   0.687295
# 3        0   0.729627   0.726485   0.715613   0.704214   0.695404   0.689836
# 4        0   0.714636   0.714388   0.706626   0.698127   0.691818   0.688184
# ..     ...        ...        ...        ...        ...        ...        ...
# 495      2   0.722422   0.720920   0.712699   0.704530   0.699261   0.697420
# 496      2   0.726260   0.726227   0.725950   0.725444   0.724643   0.723600
# 497      2   0.726733   0.724837   0.715531   0.705948   0.699105   0.695240
# 498      2   0.747386   0.745534   0.735654   0.724924   0.716467   0.710962
# 499      2   0.740270   0.738251   0.728985   0.719566   0.713096   0.710130
#
# ...

# %% [markdown]
# ### Info about raw Dataset

# %% [markdown]
# #### Shape

# %%
data.shape
# Out:
# (500, 2001)

# %% [markdown]
# #### Important info

# %%
data_description = data.describe()

df_filters = data.filter(items=['state', 'current_500', 'volt_500'])

df_filters.describe()
# Out:
#             state  current_500    volt_500
# count  500.000000   500.000000  500.000000
# mean     0.600000     0.744489   22.308466
# std      0.800801     0.113429    1.336150
# min      0.000000     0.619654   19.877501
# 25%      0.000000     0.679653   21.394608
# 50%      0.000000     0.700233   22.028684
# 75%      1.000000     0.731381   22.841397
# max      2.000000     1.081654   28.685290

# %%
for column in df_filters.columns:
    sns.histplot(data=df_filters, hue='state', x=column)
    plt.show()
    plt.clf()

# %% [markdown]
# ### Save data

# %%
data.to_csv('../data/dataset01.csv')
